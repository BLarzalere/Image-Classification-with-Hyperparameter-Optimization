# %% [markdown]
# ## Image Classification using PyTorch
# Multi-class image classification using transfer learning and hyperparameter optimization for model creation. PyTorch will be used as the deep learning development framework.

# %%
# Import libraries
import os
import time
import random
import numpy as np
from numpy import argmax
import pandas as pd
import json
from collections import OrderedDict, namedtuple
from itertools import product
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
import torchvision
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
# Enable GPU processing
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Device type: {device}')
# Out:
# Device type: cuda

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/drive', force_remount=True)
# Out:
# Mounted at /drive

# %%
# Set random seed
seed = 777
torch.manual_seed(seed)

# %%
# Define data directory parameters
datadir = '/drive/My Drive/Data/flowers/'
traindir = datadir + 'train/'
validdir = datadir + 'valid/'
testdir = datadir + 'test/'

# %%
# Confirm image class distribution

# Empty lists
classes = []
n_train = []
n_valid = []
n_test = []

# Iterate through each category
for d in os.listdir(traindir):
    classes.append(d)

    # Number of each image
    train_imgs = os.listdir(traindir + d)
    valid_imgs = os.listdir(validdir + d)
    test_imgs = os.listdir(testdir + d)
    n_train.append(len(train_imgs))
    n_valid.append(len(valid_imgs))
    n_test.append(len(test_imgs))

print(f'Classes: {classes}')
print(f'Training images per class: {n_train}')
print(f'Validation images per class: {n_valid}')
print(f'Test images per class: {n_test}')
# Out:
# Classes: ['tulip', 'sunflower', 'rose', 'daisy']
# Training images per class: [450, 450, 450, 450]
# Validation images per class: [50, 50, 50, 50]
# Test images per class: [100, 100, 100, 100]

# %% [markdown]
# ### Image Augmentation / Transforms

# %%
# Define an image transformations dictionary
image_transforms = {
    # Training set uses data augmentation
    'train':
    transforms.Compose([                        
        transforms.Resize(size=256),
        transforms.RandomAffine(degrees=(0,30)),
        transforms.RandomHorizontalFlip(), 
        transforms.CenterCrop(size=224),       
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # Imagenet standards
    ]),
    # No image augmentation for the validation and test sets
    'val':
    transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),  
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test':
    transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),  
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# %%
# Load the data from each folder
data = {
    'train':
    datasets.ImageFolder(root=traindir, transform=image_transforms['train']),
    'val':
    datasets.ImageFolder(root=validdir, transform=image_transforms['val']),
    'test':
    datasets.ImageFolder(root=testdir, transform=image_transforms['test'])
}

# %% [markdown]
# ### Create CNN Model

# %%
# Review the transfer learning model: using VGG-16
review_model = models.vgg16(pretrained=True)
print(review_model)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# test_model = nn.Sequential(*list(review_model.children())[:-1])
# print(test_model)

# %%
# Create our CNN model by modifying the output layer of the transfer learning model
def CNN_model(hidden_units, dropout, num_classes):
  transfer_model = models.vgg16(pretrained=True)
  
  # freeze the weights from training in the transfer learning model
  for param in transfer_model.parameters():
    param.requires_grad = False

  # define the overall CNN model
  model = transfer_model
  model.classifier = nn.Sequential(
    nn.Linear(in_features=25088, out_features=4096),
    nn.ReLU(inplace=True),
    nn.Dropout(dropout, inplace=False),
    nn.Linear(in_features=4096, out_features=hidden_units),
    nn.ReLU(inplace=True),
    nn.Dropout(dropout, inplace=False),
    nn.Linear(hidden_units, num_classes),
    nn.LogSoftmax(dim=1)    
  )

  return model

# %%
# Test model creation
test_model = CNN_model(256, 0.4, 4)
print(test_model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Linear(in_features=4096, out_features=256, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.4, inplace=False)
#     (6): Linear(in_features=256, out_features=4, bias=True)
#     (7): LogSoftmax(dim=1)
#   )
# )

# %%
# Confirm trainable parameters
# total_params = sum(p.numel() for p in test_model.parameters())
# print(f'Total number of parameters: {total_params:,}')
# total_trainable_params = sum(
#     p.numel() for p in test_model.parameters() if p.requires_grad)
# print(f'Number of trainable parameters: {total_trainable_params:,}')

# %% [markdown]
# ### Create Training Execution Code

# %%
# Define a class to build run execution sets based on a dictionary of hyperparameters
class RunBuilder():
  @staticmethod
  def get_runs(params):
    Run = namedtuple('Run', params.keys())
    runs = []
    for v in product(*params.values()):
      runs.append(Run(*v))
    return runs

# %%
# Create a class to manage the training / hyperparameter runs
class RunManager():
  def __init__(self):
    self.epoch_count = 0
    self.train_loss = 0
    self.train_num_correct = 0
    self.val_loss = 0
    self.val_num_correct = 0

    self.run_params = None
    self.run_count = 0
    self.run_data = []

    self.model = None
    self.train_loader = None
    self.val_loader = None
    self.tb = None

  def begin_run(self, run, model, train_loader, val_loader):
    self.run_params = run
    self.run_count += 1
    self.model = model.to(device)
    self.train_loader = train_loader
    self.val_loader = val_loader
    self.tb = SummaryWriter(log_dir=traindir + '/runs', max_queue=20, comment=f'-{run}')
    images, labels = next(iter(self.train_loader))
    images, labels = images.to(device), labels.to(device)
    self.tb.add_graph(self.model, images)

  def end_run(self):
    self.tb.close()
    self.epoch_count = 0

  def begin_epoch(self):
    self.epoch_count += 1
    self.train_loss = 0
    self.train_num_correct = 0
    self.val_loss = 0
    self.val_num_correct = 0

  def end_epoch(self):
    train_loss = self.train_loss / len(self.train_loader.dataset)
    train_accuracy = self.train_num_correct / len(self.train_loader.dataset)
    val_loss = self.val_loss / len(self.val_loader.dataset)
    val_accuracy = self.val_num_correct / len(self.val_loader.dataset)

    self.tb.add_scalar('Train Loss', train_loss, self.epoch_count)
    self.tb.add_scalar('Train Accuracy', train_accuracy, self.epoch_count)
    self.tb.add_scalar('Val Loss', val_loss, self.epoch_count)
    self.tb.add_scalar('Val Accuracy', val_accuracy, self.epoch_count)

    for name, param in self.model.named_parameters():
      self.tb.add_histogram(name, param, self.epoch_count)
      #self.tb.add_histogram(f'{name}.grad', param.grad, self.epoch_count)

    print(f'Epoch: {self.epoch_count}, Train Loss: {train_loss:.3f}, Train Acc: {train_accuracy:.3f}')
    print(f'Epoch: {self.epoch_count}, Valid Loss: {val_loss:.3f}, Valid Acc: {val_accuracy:.3f}')
    
    results = OrderedDict()
    results['run'] = self.run_count
    results['epoch'] = self.epoch_count
    results['train loss'] = train_loss
    results['train acc'] = train_accuracy
    results['valid loss'] = val_loss
    results['valid acc'] = val_accuracy

    for k, v in self.run_params._asdict().items():
      results[k] = v

    self.run_data.append(results)

  def track_loss(self, loss, mode):
    if mode == 'train':
      self.train_loss += loss.item() * self.train_loader.batch_size
    elif mode == 'val':
      self.val_loss += loss.item() * self.val_loader.batch_size

  def track_num_correct(self, preds, labels, mode):
    if mode == 'train':
      self.train_num_correct += preds.argmax(dim=1).eq(labels).sum().item()
    elif mode == 'val':
      self.val_num_correct += preds.argmax(dim=1).eq(labels).sum().item()

  def save_output(self, filename):
    if filename:
      filename = traindir + filename
      pd.DataFrame.from_dict(self.run_data, orient='columns').to_csv(f'{filename}.csv')
      
      # with open(f'{filename}.json', 'w', encoding='utf-8') as f:
      #   json.dump(self.run_data, f, ensure_ascii=False, indent=4)

      print('Results saved to disk')

    return pd.DataFrame.from_dict(self.run_data, orient='columns')

# %%
# Define training loop execution
def execution_loop(filename):
  m = RunManager()
  for run in RunBuilder.get_runs(params):

    # instantiate the neural network model
    model = CNN_model(run.hidden_units, run.dropout, run.num_classes)
    optimizer = Adam(model.parameters(), lr=run.lr)
    
    # Define the data loaders
    dataloaders = {
        'train': DataLoader(data['train'], batch_size=run.batch_size, shuffle=True, num_workers=1),
        'val': DataLoader(data['val'], batch_size=run.batch_size, shuffle=False, num_workers=1)
    }

    train_loader = dataloaders['train']
    val_loader = dataloaders['val']  
        
    m.begin_run(run, model, train_loader, val_loader)
    for epoch in range(run.n_epochs):
      m.begin_epoch()
      for batch in train_loader:
        with torch.set_grad_enabled(True):
          # get inputs/targets and move tensors to GPU
          images, labels = batch[0].to(device), batch[1].to(device)
          # clear previous gradients
          optimizer.zero_grad()
          # make prediction
          yhat = model(images)
          # calculate the loss
          loss = F.nll_loss(yhat, labels)
          # perform back prop
          loss.backward()
          # update model weights
          optimizer.step()

          m.track_loss(loss, 'train')
          m.track_num_correct(yhat, labels, 'train')

      else:
        with torch.no_grad():
          for batch in val_loader:
            images, labels = batch[0].to(device), batch[1].to(device)
            output = model(images)
            loss = F.nll_loss(output, labels)

            m.track_loss(loss, 'val')
            m.track_num_correct(output, labels, 'val')

      m.end_epoch()
    m.end_run()
  return model, m.save_output(filename)

# %%
# Define training run hyperparameters
params = OrderedDict(
    hidden_units = [256, 512],
    dropout = [0.4, 0.5],
    num_classes = [4],
    lr = [0.001],
    batch_size = [25],
    n_epochs = [40]
)

# %%
model, history = execution_loop('Run_Results')
# Out:
# Epoch: 1, Train Loss: 0.885, Train Acc: 0.744
# Epoch: 1, Valid Loss: 0.455, Valid Acc: 0.865
# Epoch: 2, Train Loss: 0.343, Train Acc: 0.881
# Epoch: 2, Valid Loss: 0.430, Valid Acc: 0.885
# Epoch: 3, Train Loss: 0.223, Train Acc: 0.922
# Epoch: 3, Valid Loss: 0.648, Valid Acc: 0.900
# Epoch: 4, Train Loss: 0.231, Train Acc: 0.923
# Epoch: 4, Valid Loss: 0.667, Valid Acc: 0.890
# Epoch: 5, Train Loss: 0.193, Train Acc: 0.939
# Epoch: 5, Valid Loss: 0.620, Valid Acc: 0.865
# Epoch: 6, Train Loss: 0.164, Train Acc: 0.944
# Epoch: 6, Valid Loss: 0.409, Valid Acc: 0.920
# Epoch: 7, Train Loss: 0.122, Train Acc: 0.959
# Epoch: 7, Valid Loss: 0.789, Valid Acc: 0.910
# Epoch: 8, Train Loss: 0.154, Train Acc: 0.950
# Epoch: 8, Valid Loss: 0.583, Valid Acc: 0.875
# Epoch: 9, Train Loss: 0.127, Train Acc: 0.958
# Epoch: 9, Valid Loss: 0.594, Valid Acc: 0.930
# Epoch: 10, Train Loss: 0.085, Train Acc: 0.973
# Epoch: 10, Valid Loss: 1.150, Valid Acc: 0.885
# Epoch: 11, Train Loss: 0.083, Train Acc: 0.975
# Epoch: 11, Valid Loss: 0.695, Valid Acc: 0.910
# Epoch: 12, Train Loss: 0.107, Train Acc: 0.969
# Epoch: 12, Valid Loss: 0.858, Valid Acc: 0.880
# Epoch: 13, Train Loss: 0.096, Train Acc: 0.973
# Epoch: 13, Valid Loss: 0.842, Valid Acc: 0.910
# Epoch: 14, Train Loss: 0.084, Train Acc: 0.974
# Epoch: 14, Valid Loss: 1.147, Valid Acc: 0.875
# Epoch: 15, Train Loss: 0.060, Train Acc: 0.983
# Epoch: 15, Valid Loss: 0.695, Valid Acc: 0.900
# Epoch: 16, Train Loss: 0.162, Train Acc: 0.965
# Epoch: 16, Valid Loss: 1.627, Valid Acc: 0.870
# Epoch: 17, Train Loss: 0.119, Train Acc: 0.971
# Epoch: 17, Valid Loss: 1.069, Valid Acc: 0.860
# Epoch: 18, Train Loss: 0.099, Train Acc: 0.980
# Epoch: 18, Valid Loss: 0.876, Valid Acc: 0.900
# Epoch: 19, Train Loss: 0.054, Train Acc: 0.981
# Epoch: 19, Valid Loss: 0.701, Valid Acc: 0.920
# Epoch: 20, Train Loss: 0.094, Train Acc: 0.972
# Epoch: 20, Valid Loss: 0.813, Valid Acc: 0.890
# Epoch: 21, Train Loss: 0.082, Train Acc: 0.983
# Epoch: 21, Valid Loss: 0.715, Valid Acc: 0.880
# Epoch: 22, Train Loss: 0.060, Train Acc: 0.989
# Epoch: 22, Valid Loss: 0.990, Valid Acc: 0.940
# Epoch: 23, Train Loss: 0.062, Train Acc: 0.982
# Epoch: 23, Valid Loss: 1.072, Valid Acc: 0.895
# Epoch: 24, Train Loss: 0.075, Train Acc: 0.984
# Epoch: 24, Valid Loss: 1.312, Valid Acc: 0.900
# Epoch: 25, Train Loss: 0.037, Train Acc: 0.988
# Epoch: 25, Valid Loss: 1.563, Valid Acc: 0.900
# Epoch: 26, Train Loss: 0.134, Train Acc: 0.980
# Epoch: 26, Valid Loss: 1.871, Valid Acc: 0.860
# Epoch: 27, Train Loss: 0.033, Train Acc: 0.988
# Epoch: 27, Valid Loss: 1.524, Valid Acc: 0.875
# Epoch: 28, Train Loss: 0.053, Train Acc: 0.989
# Epoch: 28, Valid Loss: 1.043, Valid Acc: 0.895
# Epoch: 29, Train Loss: 0.057, Train Acc: 0.985
# Epoch: 29, Valid Loss: 0.976, Valid Acc: 0.885
# Epoch: 30, Train Loss: 0.080, Train Acc: 0.979
# Epoch: 30, Valid Loss: 1.750, Valid Acc: 0.875
# Epoch: 31, Train Loss: 0.084, Train Acc: 0.982
# Epoch: 31, Valid Loss: 2.323, Valid Acc: 0.865
# Epoch: 32, Train Loss: 0.092, Train Acc: 0.980
# Epoch: 32, Valid Loss: 1.350, Valid Acc: 0.900
# Epoch: 33, Train Loss: 0.033, Train Acc: 0.992
# Epoch: 33, Valid Loss: 1.445, Valid Acc: 0.905
# Epoch: 34, Train Loss: 0.109, Train Acc: 0.980
# Epoch: 34, Valid Loss: 1.468, Valid Acc: 0.905
# Epoch: 35, Train Loss: 0.101, Train Acc: 0.978
# Epoch: 35, Valid Loss: 1.865, Valid Acc: 0.910
# Epoch: 36, Train Loss: 0.071, Train Acc: 0.985
# Epoch: 36, Valid Loss: 1.605, Valid Acc: 0.880
# Epoch: 37, Train Loss: 0.055, Train Acc: 0.984
# Epoch: 37, Valid Loss: 1.642, Valid Acc: 0.910
# Epoch: 38, Train Loss: 0.027, Train Acc: 0.993
# Epoch: 38, Valid Loss: 1.714, Valid Acc: 0.890
# Epoch: 39, Train Loss: 0.033, Train Acc: 0.989
# Epoch: 39, Valid Loss: 2.018, Valid Acc: 0.915
# Epoch: 40, Train Loss: 0.056, Train Acc: 0.991
# Epoch: 40, Valid Loss: 1.382, Valid Acc: 0.905
# Epoch: 1, Train Loss: 1.008, Train Acc: 0.727
# Epoch: 1, Valid Loss: 0.624, Valid Acc: 0.835
# Epoch: 2, Train Loss: 0.342, Train Acc: 0.873
# Epoch: 2, Valid Loss: 0.534, Valid Acc: 0.870
# Epoch: 3, Train Loss: 0.296, Train Acc: 0.902
# Epoch: 3, Valid Loss: 0.725, Valid Acc: 0.845
# Epoch: 4, Train Loss: 0.275, Train Acc: 0.915
# Epoch: 4, Valid Loss: 0.549, Valid Acc: 0.895
# Epoch: 5, Train Loss: 0.264, Train Acc: 0.922
# Epoch: 5, Valid Loss: 0.588, Valid Acc: 0.885
# Epoch: 6, Train Loss: 0.202, Train Acc: 0.936
# Epoch: 6, Valid Loss: 0.701, Valid Acc: 0.905
# Epoch: 7, Train Loss: 0.203, Train Acc: 0.946
# Epoch: 7, Valid Loss: 0.968, Valid Acc: 0.870
# Epoch: 8, Train Loss: 0.210, Train Acc: 0.941
# Epoch: 8, Valid Loss: 0.719, Valid Acc: 0.855
# Epoch: 9, Train Loss: 0.133, Train Acc: 0.958
# Epoch: 9, Valid Loss: 0.831, Valid Acc: 0.895
# Epoch: 10, Train Loss: 0.099, Train Acc: 0.964
# Epoch: 10, Valid Loss: 1.007, Valid Acc: 0.890
# Epoch: 11, Train Loss: 0.115, Train Acc: 0.971
# Epoch: 11, Valid Loss: 1.851, Valid Acc: 0.815
# Epoch: 12, Train Loss: 0.110, Train Acc: 0.967
# Epoch: 12, Valid Loss: 0.802, Valid Acc: 0.890
# Epoch: 13, Train Loss: 0.137, Train Acc: 0.969
# Epoch: 13, Valid Loss: 1.305, Valid Acc: 0.885
# Epoch: 14, Train Loss: 0.121, Train Acc: 0.964
# Epoch: 14, Valid Loss: 1.206, Valid Acc: 0.875
# Epoch: 15, Train Loss: 0.090, Train Acc: 0.976
# Epoch: 15, Valid Loss: 1.177, Valid Acc: 0.915
# Epoch: 16, Train Loss: 0.231, Train Acc: 0.949
# Epoch: 16, Valid Loss: 1.559, Valid Acc: 0.880
# Epoch: 17, Train Loss: 0.268, Train Acc: 0.939
# Epoch: 17, Valid Loss: 1.318, Valid Acc: 0.885
# Epoch: 18, Train Loss: 0.142, Train Acc: 0.966
# Epoch: 18, Valid Loss: 1.439, Valid Acc: 0.890
# Epoch: 19, Train Loss: 0.111, Train Acc: 0.973
# Epoch: 19, Valid Loss: 1.343, Valid Acc: 0.900
# Epoch: 20, Train Loss: 0.094, Train Acc: 0.974
# Epoch: 20, Valid Loss: 1.362, Valid Acc: 0.890
# Epoch: 21, Train Loss: 0.083, Train Acc: 0.981
# Epoch: 21, Valid Loss: 1.625, Valid Acc: 0.875
# Epoch: 22, Train Loss: 0.133, Train Acc: 0.971
# Epoch: 22, Valid Loss: 0.896, Valid Acc: 0.900
# Epoch: 23, Train Loss: 0.057, Train Acc: 0.983
# Epoch: 23, Valid Loss: 0.926, Valid Acc: 0.935
# Epoch: 24, Train Loss: 0.116, Train Acc: 0.981
# Epoch: 24, Valid Loss: 1.066, Valid Acc: 0.910
# Epoch: 25, Train Loss: 0.079, Train Acc: 0.978
# Epoch: 25, Valid Loss: 2.094, Valid Acc: 0.860
# Epoch: 26, Train Loss: 0.137, Train Acc: 0.975
# Epoch: 26, Valid Loss: 0.929, Valid Acc: 0.895
# Epoch: 27, Train Loss: 0.071, Train Acc: 0.981
# Epoch: 27, Valid Loss: 1.237, Valid Acc: 0.915
# Epoch: 28, Train Loss: 0.094, Train Acc: 0.980
# Epoch: 28, Valid Loss: 1.164, Valid Acc: 0.915
# Epoch: 29, Train Loss: 0.070, Train Acc: 0.985
# Epoch: 29, Valid Loss: 1.335, Valid Acc: 0.905
# Epoch: 30, Train Loss: 0.052, Train Acc: 0.983
# Epoch: 30, Valid Loss: 1.726, Valid Acc: 0.880
# Epoch: 31, Train Loss: 0.087, Train Acc: 0.983
# Epoch: 31, Valid Loss: 1.697, Valid Acc: 0.900
# Epoch: 32, Train Loss: 0.068, Train Acc: 0.982
# Epoch: 32, Valid Loss: 1.720, Valid Acc: 0.870
# Epoch: 33, Train Loss: 0.065, Train Acc: 0.986
# Epoch: 33, Valid Loss: 1.978, Valid Acc: 0.885
# Epoch: 34, Train Loss: 0.133, Train Acc: 0.980
# Epoch: 34, Valid Loss: 2.796, Valid Acc: 0.865
# Epoch: 35, Train Loss: 0.221, Train Acc: 0.967
# Epoch: 35, Valid Loss: 1.293, Valid Acc: 0.895
# Epoch: 36, Train Loss: 0.147, Train Acc: 0.967
# Epoch: 36, Valid Loss: 1.074, Valid Acc: 0.925
# Epoch: 37, Train Loss: 0.118, Train Acc: 0.978
# Epoch: 37, Valid Loss: 1.894, Valid Acc: 0.895
# Epoch: 38, Train Loss: 0.106, Train Acc: 0.982
# Epoch: 38, Valid Loss: 2.290, Valid Acc: 0.900
# Epoch: 39, Train Loss: 0.112, Train Acc: 0.979
# Epoch: 39, Valid Loss: 2.562, Valid Acc: 0.880
# Epoch: 40, Train Loss: 0.109, Train Acc: 0.982
# Epoch: 40, Valid Loss: 1.880, Valid Acc: 0.905
# Epoch: 1, Train Loss: 0.859, Train Acc: 0.758
# Epoch: 1, Valid Loss: 0.393, Valid Acc: 0.875
# Epoch: 2, Train Loss: 0.321, Train Acc: 0.888
# Epoch: 2, Valid Loss: 0.448, Valid Acc: 0.860
# Epoch: 3, Train Loss: 0.236, Train Acc: 0.914
# Epoch: 3, Valid Loss: 0.490, Valid Acc: 0.880
# Epoch: 4, Train Loss: 0.188, Train Acc: 0.941
# Epoch: 4, Valid Loss: 0.607, Valid Acc: 0.895
# Epoch: 5, Train Loss: 0.184, Train Acc: 0.940
# Epoch: 5, Valid Loss: 0.700, Valid Acc: 0.890
# Epoch: 6, Train Loss: 0.169, Train Acc: 0.945
# Epoch: 6, Valid Loss: 0.627, Valid Acc: 0.870
# Epoch: 7, Train Loss: 0.143, Train Acc: 0.956
# Epoch: 7, Valid Loss: 0.932, Valid Acc: 0.905
# Epoch: 8, Train Loss: 0.162, Train Acc: 0.954
# Epoch: 8, Valid Loss: 0.910, Valid Acc: 0.905
# Epoch: 9, Train Loss: 0.139, Train Acc: 0.966
# Epoch: 9, Valid Loss: 0.993, Valid Acc: 0.865
# Epoch: 10, Train Loss: 0.116, Train Acc: 0.966
# Epoch: 10, Valid Loss: 1.049, Valid Acc: 0.910
# Epoch: 11, Train Loss: 0.139, Train Acc: 0.958
# Epoch: 11, Valid Loss: 1.120, Valid Acc: 0.855
# Epoch: 12, Train Loss: 0.090, Train Acc: 0.974
# Epoch: 12, Valid Loss: 0.947, Valid Acc: 0.910
# Epoch: 13, Train Loss: 0.093, Train Acc: 0.972
# Epoch: 13, Valid Loss: 1.086, Valid Acc: 0.905
# Epoch: 14, Train Loss: 0.086, Train Acc: 0.979
# Epoch: 14, Valid Loss: 1.098, Valid Acc: 0.915
# Epoch: 15, Train Loss: 0.118, Train Acc: 0.979
# Epoch: 15, Valid Loss: 1.676, Valid Acc: 0.875
# Epoch: 16, Train Loss: 0.085, Train Acc: 0.973
# Epoch: 16, Valid Loss: 1.363, Valid Acc: 0.900
# Epoch: 17, Train Loss: 0.109, Train Acc: 0.977
# Epoch: 17, Valid Loss: 1.258, Valid Acc: 0.910
# Epoch: 18, Train Loss: 0.084, Train Acc: 0.979
# Epoch: 18, Valid Loss: 1.320, Valid Acc: 0.885
# Epoch: 19, Train Loss: 0.072, Train Acc: 0.981
# Epoch: 19, Valid Loss: 1.113, Valid Acc: 0.895
# Epoch: 20, Train Loss: 0.068, Train Acc: 0.984
# Epoch: 20, Valid Loss: 1.341, Valid Acc: 0.895
# Epoch: 21, Train Loss: 0.122, Train Acc: 0.971
# Epoch: 21, Valid Loss: 1.633, Valid Acc: 0.895
# Epoch: 22, Train Loss: 0.171, Train Acc: 0.969
# Epoch: 22, Valid Loss: 1.867, Valid Acc: 0.870
# Epoch: 23, Train Loss: 0.117, Train Acc: 0.976
# Epoch: 23, Valid Loss: 1.762, Valid Acc: 0.855
# Epoch: 24, Train Loss: 0.107, Train Acc: 0.975
# Epoch: 24, Valid Loss: 1.141, Valid Acc: 0.900
# Epoch: 25, Train Loss: 0.095, Train Acc: 0.983
# Epoch: 25, Valid Loss: 0.709, Valid Acc: 0.920
# Epoch: 26, Train Loss: 0.043, Train Acc: 0.990
# Epoch: 26, Valid Loss: 1.402, Valid Acc: 0.875
# Epoch: 27, Train Loss: 0.124, Train Acc: 0.979
# Epoch: 27, Valid Loss: 1.391, Valid Acc: 0.915
# Epoch: 28, Train Loss: 0.098, Train Acc: 0.986
# Epoch: 28, Valid Loss: 1.489, Valid Acc: 0.885
# Epoch: 29, Train Loss: 0.067, Train Acc: 0.983
# Epoch: 29, Valid Loss: 1.715, Valid Acc: 0.890
# Epoch: 30, Train Loss: 0.101, Train Acc: 0.981
# Epoch: 30, Valid Loss: 1.440, Valid Acc: 0.870
# Epoch: 31, Train Loss: 0.080, Train Acc: 0.982
# Epoch: 31, Valid Loss: 1.519, Valid Acc: 0.910
# Epoch: 32, Train Loss: 0.033, Train Acc: 0.991
# Epoch: 32, Valid Loss: 1.534, Valid Acc: 0.885
# Epoch: 33, Train Loss: 0.047, Train Acc: 0.987
# Epoch: 33, Valid Loss: 1.945, Valid Acc: 0.895
# Epoch: 34, Train Loss: 0.077, Train Acc: 0.986
# Epoch: 34, Valid Loss: 1.865, Valid Acc: 0.880
# Epoch: 35, Train Loss: 0.094, Train Acc: 0.985
# Epoch: 35, Valid Loss: 1.244, Valid Acc: 0.895
# Epoch: 36, Train Loss: 0.036, Train Acc: 0.987
# Epoch: 36, Valid Loss: 1.879, Valid Acc: 0.915
# Epoch: 37, Train Loss: 0.070, Train Acc: 0.985
# Epoch: 37, Valid Loss: 2.735, Valid Acc: 0.880
# Epoch: 38, Train Loss: 0.080, Train Acc: 0.983
# Epoch: 38, Valid Loss: 3.088, Valid Acc: 0.890
# Epoch: 39, Train Loss: 0.073, Train Acc: 0.984
# Epoch: 39, Valid Loss: 1.796, Valid Acc: 0.895
# Epoch: 40, Train Loss: 0.037, Train Acc: 0.990
# Epoch: 40, Valid Loss: 1.757, Valid Acc: 0.900
# Epoch: 1, Train Loss: 1.031, Train Acc: 0.728
# Epoch: 1, Valid Loss: 0.511, Valid Acc: 0.855
# Epoch: 2, Train Loss: 0.394, Train Acc: 0.860
# Epoch: 2, Valid Loss: 0.429, Valid Acc: 0.875
# Epoch: 3, Train Loss: 0.233, Train Acc: 0.919
# Epoch: 3, Valid Loss: 0.475, Valid Acc: 0.865
# Epoch: 4, Train Loss: 0.231, Train Acc: 0.924
# Epoch: 4, Valid Loss: 0.846, Valid Acc: 0.860
# Epoch: 5, Train Loss: 0.259, Train Acc: 0.928
# Epoch: 5, Valid Loss: 0.585, Valid Acc: 0.875
# Epoch: 6, Train Loss: 0.201, Train Acc: 0.938
# Epoch: 6, Valid Loss: 0.982, Valid Acc: 0.860
# Epoch: 7, Train Loss: 0.177, Train Acc: 0.953
# Epoch: 7, Valid Loss: 0.588, Valid Acc: 0.920
# Epoch: 8, Train Loss: 0.160, Train Acc: 0.954
# Epoch: 8, Valid Loss: 0.915, Valid Acc: 0.890
# Epoch: 9, Train Loss: 0.135, Train Acc: 0.961
# Epoch: 9, Valid Loss: 1.199, Valid Acc: 0.870
# Epoch: 10, Train Loss: 0.142, Train Acc: 0.961
# Epoch: 10, Valid Loss: 0.785, Valid Acc: 0.855
# Epoch: 11, Train Loss: 0.129, Train Acc: 0.968
# Epoch: 11, Valid Loss: 0.991, Valid Acc: 0.870
# Epoch: 12, Train Loss: 0.162, Train Acc: 0.954
# Epoch: 12, Valid Loss: 0.907, Valid Acc: 0.880
# Epoch: 13, Train Loss: 0.138, Train Acc: 0.962
# Epoch: 13, Valid Loss: 1.678, Valid Acc: 0.830
# Epoch: 14, Train Loss: 0.153, Train Acc: 0.967
# Epoch: 14, Valid Loss: 1.328, Valid Acc: 0.890
# Epoch: 15, Train Loss: 0.176, Train Acc: 0.964
# Epoch: 15, Valid Loss: 0.909, Valid Acc: 0.880
# Epoch: 16, Train Loss: 0.149, Train Acc: 0.967
# Epoch: 16, Valid Loss: 0.802, Valid Acc: 0.930
# Epoch: 17, Train Loss: 0.141, Train Acc: 0.965
# Epoch: 17, Valid Loss: 1.501, Valid Acc: 0.865
# Epoch: 18, Train Loss: 0.100, Train Acc: 0.974
# Epoch: 18, Valid Loss: 0.993, Valid Acc: 0.910
# Epoch: 19, Train Loss: 0.124, Train Acc: 0.970
# Epoch: 19, Valid Loss: 1.256, Valid Acc: 0.900
# Epoch: 20, Train Loss: 0.128, Train Acc: 0.968
# Epoch: 20, Valid Loss: 1.370, Valid Acc: 0.895
# Epoch: 21, Train Loss: 0.119, Train Acc: 0.973
# Epoch: 21, Valid Loss: 2.046, Valid Acc: 0.865
# Epoch: 22, Train Loss: 0.202, Train Acc: 0.966
# Epoch: 22, Valid Loss: 1.592, Valid Acc: 0.895
# Epoch: 23, Train Loss: 0.120, Train Acc: 0.976
# Epoch: 23, Valid Loss: 2.089, Valid Acc: 0.875
# Epoch: 24, Train Loss: 0.146, Train Acc: 0.973
# Epoch: 24, Valid Loss: 1.251, Valid Acc: 0.920
# Epoch: 25, Train Loss: 0.129, Train Acc: 0.976
# Epoch: 25, Valid Loss: 1.755, Valid Acc: 0.890
# Epoch: 26, Train Loss: 0.073, Train Acc: 0.983
# Epoch: 26, Valid Loss: 1.721, Valid Acc: 0.905
# Epoch: 27, Train Loss: 0.077, Train Acc: 0.982
# Epoch: 27, Valid Loss: 2.484, Valid Acc: 0.865
# Epoch: 28, Train Loss: 0.126, Train Acc: 0.978
# Epoch: 28, Valid Loss: 2.631, Valid Acc: 0.880
# Epoch: 29, Train Loss: 0.091, Train Acc: 0.984
# Epoch: 29, Valid Loss: 2.451, Valid Acc: 0.890
# Epoch: 30, Train Loss: 0.152, Train Acc: 0.977
# Epoch: 30, Valid Loss: 2.151, Valid Acc: 0.905
# Epoch: 31, Train Loss: 0.211, Train Acc: 0.974
# Epoch: 31, Valid Loss: 1.917, Valid Acc: 0.870
# Epoch: 32, Train Loss: 0.122, Train Acc: 0.981
# Epoch: 32, Valid Loss: 2.142, Valid Acc: 0.905
# Epoch: 33, Train Loss: 0.173, Train Acc: 0.970
# Epoch: 33, Valid Loss: 1.764, Valid Acc: 0.900
# Epoch: 34, Train Loss: 0.135, Train Acc: 0.978
# Epoch: 34, Valid Loss: 2.454, Valid Acc: 0.870
# Epoch: 35, Train Loss: 0.102, Train Acc: 0.983
# Epoch: 35, Valid Loss: 1.499, Valid Acc: 0.880
# Epoch: 36, Train Loss: 0.110, Train Acc: 0.979
# Epoch: 36, Valid Loss: 2.124, Valid Acc: 0.900
# Epoch: 37, Train Loss: 0.150, Train Acc: 0.978
# Epoch: 37, Valid Loss: 1.863, Valid Acc: 0.875
# Epoch: 38, Train Loss: 0.083, Train Acc: 0.984
# Epoch: 38, Valid Loss: 2.146, Valid Acc: 0.910
# Epoch: 39, Train Loss: 0.142, Train Acc: 0.982
# Epoch: 39, Valid Loss: 3.167, Valid Acc: 0.910
# Epoch: 40, Train Loss: 0.091, Train Acc: 0.982
# Epoch: 40, Valid Loss: 2.609, Valid Acc: 0.890
# Results saved to disk

# %%
# View single run loss curves
# plt.figure(figsize=(10, 8))
# plt.plot(history['train loss'], label='Training', linewidth=3)
# plt.plot(history['valid loss'], label='Validation', linewidth=3)
# plt.title('Training and Validation Losses', fontsize=16)
# plt.ylabel('Average Negative Log Likelihood')
# plt.xlabel('Epoch')
# plt.legend(loc='upper right')
# plt.show();

# %%
# View single run accuracy curves
# plt.figure(figsize=(10, 8))
# plt.plot(history['train acc'], label='Training', linewidth=3)
# plt.plot(history['valid acc'], label='Validation', linewidth=3)
# plt.title('Training and Validation Accuracy', fontsize=16)
# plt.ylabel('Average Accuracy')
# plt.xlabel('Epoch')
# plt.legend(loc='lower right')
# plt.show();

# %%
# Function to evaluate the model on the test set
def evaluate_model(test_dl, model):
    predictions, actuals = list(), list()
    for i, (inputs, targets) in enumerate(test_dl):
        # evaluate the model on the test set
        yhat = model(inputs)
        # retrieve numpy array
        yhat = yhat.detach().numpy()
        actual = targets.numpy()
        actual = actual.reshape((len(actual), 1))
        # round to class values
        yhat = yhat.round()
        # store
        predictions.append(yhat)
        actuals.append(actual)
    predictions, actuals = vstack(predictions), vstack(actuals)
    # calculate accuracy
    acc = accuracy_score(actuals, predictions)
    return acc

# %%
# Determine model accuracy on the test set
test_dl = DataLoader(data['test'], batch_size=params['batch_size'], shuffle=False, num_workers=1)
test_acc = evaluate_model(test_dl, model)
